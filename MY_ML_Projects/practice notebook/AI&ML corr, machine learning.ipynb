# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
flights=sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips=sns.load_dataset("tips")

# %% [markdown]
# ### heatmap correlation

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(),cmap="coolwarm",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### pivot tables

# %%
flights.pivot_table(values="passengers",index="month",columns="year")
#sns.heatmap(pvflights)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
pvflights=flights.pivot_table(values="passengers",index="month",columns="year")
sns.heatmap(pvflights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
ufo=pd.read_csv("c:Downloads/AI &ML_datasets/ufo.csv")
ufo=ufo.iloc[:,1:]
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             Red       TRIANGLE    NY
# 1               Willingboro             Red          OTHER    NJ
# 2                   Holyoke             Red           OVAL    CO
# 3                   Abilene             Red           DISK    KS
# 4      New York Worlds Fair             Red          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             Red       TRIANGLE    IL
# 18237           Spirit Lake             Red           DISK    IA
# 18238           Eagle River             Red          LIGHT    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             Red           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo["Time"]=pd.to_datetime(ufo["Time"])
ufo["Month"]=ufo["Time"].dt.month
ufo["Year"]=ufo["Time"].dt.year
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             Red       TRIANGLE    NY
# 1               Willingboro             Red          OTHER    NJ
# 2                   Holyoke             Red           OVAL    CO
# 3                   Abilene             Red           DISK    KS
# 4      New York Worlds Fair             Red          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             Red       TRIANGLE    IL
# 18237           Spirit Lake             Red           DISK    IA
# 18238           Eagle River             Red          LIGHT    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             Red           OVAL    FL
#
#                      Time  Month  Year
# 0     1930-06-01 22:00:00      6  1930
# 1     1930-06-30 20:00:00      6  1930
# 2     1931-02-15 14:00:00      2  1931
# ...

# %%
ufo[ufo["Year"]==2000]
ufo.groupby(["Year","Month"]).count()[["Time"]].reset_index().sort_values("Year",ascending=True)
# Out:
#      Year  Month  Time
# 0    1930      6     2
# 1    1931      2     1
# 2    1931      6     1
# 3    1933      4     1
# 4    1934      9     1
# ..    ...    ...   ...
# 629  2000      2   178
# 628  2000      1   198
# 638  2000     11   200
# 632  2000      5   154
# 639  2000     12   192
#
# [640 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
hat.rename(columns={"Time","Recordings"},inplace=True)
#sns.heatmap()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MAHEND~1\AppData\Local\Temp/ipykernel_13540/2461037042.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(10,10))
# ----> 3 hat.rename(columns={"Time","Recordings"},inplace=True)
#       4 #sns.heatmap()
#
# NameError: name 'hat' is not defined

# %% [markdown]
# types of machine learning
# mainly
# 1 supervised learning
# 2 unsupervised learning
# 3 reinforcement learning

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("c:Downloads/AI &ML_datasets/50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#model.intercept_,coef_
#linear,logistic regression 03/09/2022
