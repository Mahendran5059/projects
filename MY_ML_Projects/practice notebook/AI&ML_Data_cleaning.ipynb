# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
car=pd.read_csv("c:Downloads/AI &ML_datasets/Car_sales.csv")
plact=pd.read_csv("c:Downloads/AI &ML_datasets/Placement_Data.csv")
plact.head()
car.head()
# Out:
#     Manufacturer              Model  Sales in thousands  x_4_year  \
# 0  Acura          Integra                        16.919    16.360
# 1  Acura          TL                             39.384    19.875
# 2  Acura          CL                             14.114    18.225
# 3  Acura          RL                              8.588    29.725
# 4  Audi           A4                             20.397    22.255
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        154 non-null    object
#  1   Model               157 non-null    object
#  2   Sales in thousands  157 non-null    float64
#  3   x_4_year            121 non-null    float64
#  4   Vehicle type        157 non-null    object
#  5   Price in thousands  155 non-null    float64
#  6   Engine size         156 non-null    float64
#  7   Horsepower          156 non-null    float64
#  8   Wheelbase           156 non-null    float64
#  9   Width               156 non-null    float64
#  10  Length              156 non-null    float64
#  11  Curb weight         155 non-null    float64
#  12  Fuel capacity       156 non-null    float64
#  13  Fuel efficiency     154 non-null    float64
#  14  Latest Launch       157 non-null    object
# ...

# %%
car["Latest Launch"].values
# Out:
# array(['2-Feb-14', '6-Mar-15', '1-Apr-14', '3-Oct-15', '10-Aug-15',
#        '8-Sep-15', '27-Feb-14', '28-Jun-15', '29-Jan-14', '4-Apr-15',
#        '11-Feb-15', '9-Mar-15', '23-Mar-14', '23-Jul-15', '23-Feb-14',
#        '29-Apr-15', '27-Nov-15', '28-Sep-15', '17-Apr-14', '17-Aug-15',
#        '19-Mar-14', '24-May-15', '22-Dec-15', '23-Oct-15', '5-Dec-14',
#        '9-Nov-15', '13-Apr-14', '18-Jun-15', '16-Jan-14', '17-Nov-15',
#        '6-Jun-14', '10-Jun-15', '5-Aug-14', '13-Jul-15', '2-Oct-14',
#        '12-Dec-15', '7-Jan-14', '31-Oct-15', '6-Feb-14', '8-Jul-15',
#        '3-Jun-14', '1-Jun-14', '26-Jul-14', '25-Nov-15', '27-Jun-14',
#        '9-Jan-15', '31-Mar-14', '31-Jan-14', '20-Aug-14', '20-Dec-15',
#        '22-Jul-14', '26-Sep-15', '25-Apr-14', '25-Feb-14', '14-Sep-14',
#        '14-Jan-14', '16-Aug-14', '21-Oct-15', '20-May-14', '21-Mar-14',
#        '10-Sep-14', '2-Aug-14', '9-Oct-14', '15-Nov-15', '14-Jun-14',
# ...

# %%
car.isnull().sum()
# Out:
# Manufacturer            3
# Model                   0
# Sales in thousands      0
# x_4_year               36
# Vehicle type            0
# Price in thousands      2
# Engine size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb weight             2
# Fuel capacity           1
# Fuel efficiency         3
# Latest Launch           0
# Unnamed: 15           157
# XX                     36
# dtype: int64

# %%
car[['Sales in thousands','x_4_year','Price in thousands','Engine size','Horsepower','Wheelbase','Width','Length','Curb weight','Fuel capacity',
    'Fuel efficiency']]=car[['Sales in thousands','x_4_year','Price in thousands','Engine size','Horsepower','Wheelbase','Width','Length','Curb weight','Fuel capacity',
    'Fuel efficiency']].fillna(car[['Sales in thousands','x_4_year','Price in thousands','Engine size','Horsepower','Wheelbase','Width','Length','Curb weight','Fuel capacity',
    'Fuel efficiency']].median())
car['XX']=car['XX'].fillna(car['XX'].median())
#fill nan values  with median in all columns
#df=df.fillna(df.median()) or df.fillna(df.median(), inplace=True) we inplace instead overwrite
car.isnull().sum()
# if we want to delete that row then
#data.dropna(inplace=True)
# Out:
# Manufacturer            3
# Model                   0
# Sales in thousands      0
# x_4_year                0
# Vehicle type            0
# Price in thousands      0
# Engine size             0
# Horsepower              0
# Wheelbase               0
# Width                   0
# Length                  0
# Curb weight             0
# Fuel capacity           0
# Fuel efficiency         0
# Latest Launch           0
# Unnamed: 15           157
# XX                      0
# dtype: int64

# %%
car["Manufacturer"].values
# Out:
# array(['Acura        ', 'Acura        ', 'Acura        ', 'Acura        ',
#        'Audi         ', 'Audi         ', 'Audi         ', nan, nan, nan,
#        'Buick        ', 'Buick        ', 'Buick        ', 'Buick        ',
#        'Cadillac     ', 'Cadillac     ', 'Cadillac     ', 'Cadillac     ',
#        'Cadillac     ', 'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ',
#        'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ',
#        'Chevrolet    ', 'Chevrolet    ', 'Chrysler     ', 'Chrysler     ',
#        'Chrysler     ', 'Chrysler     ', 'Chrysler     ', 'Chrysler     ',
#        'Chrysler     ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Ford         ', 'Ford         ', 'Ford         ', 'Ford         ',
#        'Ford         ', 'Ford         ', 'Ford         ', 'Ford         ',
# ...

# %%
car["Manufacturer"].fillna("BMW",inplace=True)
car["Manufacturer"].values
# Out:
# array(['Acura        ', 'Acura        ', 'Acura        ', 'Acura        ',
#        'Audi         ', 'Audi         ', 'Audi         ', 'BMW', 'BMW',
#        'BMW', 'Buick        ', 'Buick        ', 'Buick        ',
#        'Buick        ', 'Cadillac     ', 'Cadillac     ', 'Cadillac     ',
#        'Cadillac     ', 'Cadillac     ', 'Chevrolet    ', 'Chevrolet    ',
#        'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ',
#        'Chevrolet    ', 'Chevrolet    ', 'Chevrolet    ', 'Chrysler     ',
#        'Chrysler     ', 'Chrysler     ', 'Chrysler     ', 'Chrysler     ',
#        'Chrysler     ', 'Chrysler     ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Dodge        ', 'Dodge        ', 'Dodge        ',
#        'Dodge        ', 'Ford         ', 'Ford         ', 'Ford         ',
#        'Ford         ', 'Ford         ', 'Ford         ', 'Ford         ',
# ...

# %%
car["Manufacturer"].mode()
# Out:
# 0    Dodge
# 1    Ford
# dtype: object

# %%
plact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
plact['specialisation'].values
# Out:
# array(['Mkt&HR', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin', 'Mkt&Fin',
#        'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin',
#        'Mkt&HR', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin',
#        'Mkt&HR', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin',
#        'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin', 'Mkt&Fin',
#        'Mkt&HR', 'Mkt&HR', 'Mkt&HR', 'Mkt&Fin', 'Mkt&HR', 'Mkt&HR',
#        'Mkt&Fin', 'Mkt&HR', 'Mkt&HR', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&HR',
#        'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin', 'Mkt&HR', 'Mkt&HR', 'Mkt&Fin',
#        'Mkt&Fin', 'Mkt&HR', 'Mkt&HR', 'Mkt&HR', 'Mkt&HR', 'Mkt&HR',
#        'Mkt&HR', 'Mkt&HR', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin',
#        'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin', 'Mkt&HR',
#        'Mkt&HR', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin',
#        'Mkt&Fin', 'Mkt&Fin', 'Mkt&Fin', 'Mkt&HR', 'Mkt&Fin', 'Mkt&Fin',
# ...

# %%
plact.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
plact["salary"].fillna(plact["salary"].median(),inplace=True)
plact.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
car[car["Manufacturer"]=="Audi"]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, x_4_year, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch, Unnamed: 15, XX]
# Index: []

# %%
#there is no values bcoz there is an extra space in values
#remove it
car["Manufacturer"]=car["Manufacturer"].str.strip()
car["Model"]=car["Model"].str.strip()# rstrip() - right,lstrip- left this method also there
car["Manufacturer"].values
# Out:
# array(['Acura', 'Acura', 'Acura', 'Acura', 'Audi', 'Audi', 'Audi', 'BMW',
#        'BMW', 'BMW', 'Buick', 'Buick', 'Buick', 'Buick', 'Cadillac',
#        'Cadillac', 'Cadillac', 'Cadillac', 'Cadillac', 'Chevrolet',
#        'Chevrolet', 'Chevrolet', 'Chevrolet', 'Chevrolet', 'Chevrolet',
#        'Chevrolet', 'Chevrolet', 'Chevrolet', 'Chrysler', 'Chrysler',
#        'Chrysler', 'Chrysler', 'Chrysler', 'Chrysler', 'Chrysler',
#        'Dodge', 'Dodge', 'Dodge', 'Dodge', 'Dodge', 'Dodge', 'Dodge',
#        'Dodge', 'Dodge', 'Dodge', 'Dodge', 'Ford', 'Ford', 'Ford', 'Ford',
#        'Ford', 'Ford', 'Ford', 'Ford', 'Ford', 'Ford', 'Ford', 'Honda',
#        'Honda', 'Honda', 'Honda', 'Honda', 'Hyundai', 'Hyundai',
#        'Hyundai', 'Infiniti', 'Jaguar', 'Jeep', 'Jeep', 'Jeep', 'Lexus',
#        'Lexus', 'Lexus', 'Lexus', 'Lexus', 'Lexus', 'Lincoln', 'Lincoln',
#        'Lincoln', 'Mitsubishi', 'Mitsubishi', 'Mitsubishi', 'Mitsubishi',
# ...

# %%
car[car['Manufacturer']=="Ford"][["Manufacturer","Model","Price in thousands","Sales in thousands"]]
# Out:
#    Manufacturer           Model  Price in thousands  Sales in thousands
# 46         Ford          Escort              12.070              70.227
# 47         Ford         Mustang              21.560             113.369
# 48         Ford         Contour              17.035              35.068
# 49         Ford          Taurus              17.885             245.815
# 50         Ford           Focus              12.315             175.670
# 51         Ford  Crown Victoria              22.195              63.403
# 52         Ford        Explorer              31.930             276.747
# 53         Ford        Windstar              21.410             155.787
# 54         Ford      Expedition              36.135             125.338
# 55         Ford          Ranger              12.050             220.650
# 56         Ford        F-Series              26.935             540.561

# %% [markdown]
# Requirements-find out top 5 models from ford and dodge cars additionally with price , fuel efficiency,fuel capacity

# %%
x1=car[car["Manufacturer"]=="Ford"].sort_values("Sales in thousands",ascending=False).head()
x2=car[car["Manufacturer"]=="Dodge"].sort_values("Sales in thousands",ascending=False).head()
final=pd.concat([x1,x2],axis=0).sort_values("Sales in thousands",ascending=False)
final[["Manufacturer","Model","Price in thousands","Fuel capacity","Fuel efficiency"]]
# Out:
#    Manufacturer       Model  Price in thousands  Fuel capacity  \
# 56         Ford    F-Series              26.935           25.1
# 52         Ford    Explorer              31.930           21.0
# 49         Ford      Taurus              17.885           16.0
# 40        Dodge  Ram Pickup              19.460           26.0
# 55         Ford      Ranger              12.050           20.0
# 45        Dodge     Caravan              19.565           20.0
# 50         Ford       Focus              12.315           13.2
# 43        Dodge      Dakota              16.980           22.0
# 44        Dodge     Durango              26.310           25.0
# 38        Dodge    Intrepid              22.505           17.0
#
#     Fuel efficiency
# 56             18.0
# 52             19.0
# 49             24.0
# 40             17.0
# 55             23.0
# 45             24.0
# 50             30.0
# 43             19.0
# 44             17.0
# 38             24.0

# %%
car.groupby("Manufacturer").mean()[["Sales in thousands","Price in thousands"]]
# Out:
#                Sales in thousands  Price in thousands
# Manufacturer
# Acura                   19.751250           28.674750
# Audi                    13.519000           39.980000
# BMW                     15.501667           33.096667
# Buick                   60.504750           26.781250
# Cadillac                22.435600           40.254000
# Chevrolet               61.596111           20.022778
# Chrysler                28.817286           23.340571
# Dodge                   82.740818           24.213636
# Ford                   183.875909           21.047273
# Honda                  118.534800           20.277000
# Hyundai                 45.775333           12.165667
# Infiniti                23.713000           29.465000
# Jaguar                  15.467000           42.800000
# Jeep                    97.717667           20.991667
# Lexus                   17.807167           44.055000
# Lincoln                 28.544667           41.690000
# ...

# %%
car.groupby(["Manufacturer","Vehicle type","Model"]).mean()[["Sales in thousands","Price in thousands"]].head(50)
# Out:
#                                           Sales in thousands  \
# Manufacturer Vehicle type Model
# Acura        Passenger    CL                          14.114
#                           Integra                     16.919
#                           RL                           8.588
#                           TL                          39.384
# Audi         Passenger    A4                          20.397
#                           A6                          18.780
#                           A8                           1.380
# BMW          Passenger    323i                        19.747
#                           328i                         9.231
#                           528i                        17.527
# Buick        Passenger    Century                     91.561
#                           LeSabre                     83.257
#                           Park Avenue                 27.851
#                           Regal                       39.350
# ...

# %%
car.describe()#pd.set_option('display.max_rows',None) to see full dataset
# Out:
#        Sales in thousands    x_4_year  Price in thousands  Engine size  \
# count          157.000000  157.000000          157.000000   157.000000
# mean            52.998076   17.180318           27.332261     3.060510
# std             68.029422   10.178562           14.268713     1.041311
# min              0.110000    5.160000            9.235000     1.000000
# 25%             14.114000   12.545000           18.145000     2.300000
# 50%             29.450000   14.180000           22.799000     3.000000
# 75%             67.956000   18.140000           31.930000     3.500000
# max            540.561000   67.550000           85.500000     8.000000
#
#        Horsepower   Wheelbase       Width      Length  Curb weight  \
# count  157.000000  157.000000  157.000000  157.000000   157.000000
# mean   185.894904  107.484076   71.146178  187.347134     3.377567
# std     56.522319    7.616872    3.441124   13.388708     0.626460
# ...

# %%
# which company manufacturer the most efficient cars
car.groupby("Manufacturer").mean().sort_values("Fuel efficiency",ascending=False).head()
# Out:
#               Sales in thousands   x_4_year  Price in thousands  Engine size  \
# Manufacturer
# Saturn                 33.770000  11.788000           14.271000     2.020000
# Chevrolet              61.596111  13.336111           20.022778     3.055556
# Hyundai                45.775333   7.531667           12.165667     1.966667
# Volkswagen             34.868667  14.317500           17.698333     1.966667
# Acura                  19.751250  21.046250           28.674750     2.925000
#
#               Horsepower   Wheelbase      Width      Length  Curb weight  \
# Manufacturer
# Saturn        119.600000  104.040000  67.440000  182.920000     2.627200
# Chevrolet     171.111111  103.933333  70.277778  185.188889     2.976556
# Hyundai       126.666667  100.933333  68.066667  175.366667     2.646000
# Volkswagen    120.833333   99.900000  68.000000  167.416667     2.878833
# Acura         200.000000  107.700000  69.900000  188.475000     3.369000
#
# ...

# %%
#Top 10 worst companies with Poor sales
car.groupby("Manufacturer").sum().sort_values("Sales in thousands",ascending=True)["Sales in thousands"].head(10)
# Out:
# Manufacturer
# Porsche     12.128
# Jaguar      15.467
# Saab        21.306
# Infiniti    23.713
# Audi        40.557
# BMW         46.505
# Plymouth    64.001
# Volvo       75.740
# Acura       79.005
# Subaru      80.135
# Name: Sales in thousands, dtype: float64

# %%
#top 10 best companies with Best Price
car.groupby("Manufacturer").min().sort_values("Price in thousands")["Price in thousands"].head(10)
# Out:
# Manufacturer
# Chevrolet      9.235
# Hyundai        9.699
# Saturn        10.685
# Toyota        11.528
# Ford          12.050
# Plymouth      12.640
# Dodge         12.640
# Honda         12.885
# Nissan        13.499
# Mitsubishi    13.987
# Name: Price in thousands, dtype: float64

# %%
### OR

car.groupby("Manufacturer").mean().sort_values("Price in thousands")["Price in thousands"].head(10)
# Out:
# Manufacturer
# Hyundai       12.165667
# Saturn        14.271000
# Volkswagen    17.698333
# Chevrolet     20.022778
# Honda         20.277000
# Mercury       20.748333
# Jeep          20.991667
# Ford          21.047273
# Subaru        21.395000
# Toyota        21.982889
# Name: Price in thousands, dtype: float64

# %%
#top 10 companies that manufacturers widest cars
#car.groupby("Manufacturer").count().sort_values("Model",ascending=False)["Model"].head(10)
car.groupby("Manufacturer").mean().sort_values("Width",ascending=False)["Width"].head(10)
# Out:
# Manufacturer
# Lincoln     77.233333
# Dodge       74.709091
# Plymouth    74.625000
# Cadillac    74.460000
# Buick       73.400000
# Ford        72.845455
# Audi        72.766667
# Mercury     72.500000
# Lexus       72.033333
# Chrysler    71.950000
# Name: Width, dtype: float64

# %%
#top 10 companies that manufactures smallest cars
car.groupby("Manufacturer").mean().sort_values("Length")["Length"].head(10)
# Out:
# Manufacturer
# Jeep             167.000000
# Volkswagen       167.416667
# Porsche          173.333333
# Hyundai          175.366667
# Plymouth         178.100000
# Mercedes-Benz    179.966667
# BMW              180.000000
# Subaru           180.500000
# Toyota           181.855556
# Mitsubishi       182.300000
# Name: Length, dtype: float64
